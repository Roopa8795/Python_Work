# %%
age=int(input("Enter your age:"))
monthly_income=int(input("Enter your monthly income:"))
credit_score=int(input("Enter your credit score:"))
employement_status=input("Enter your employement status(employed/unemployed):")
if age<21:
    print("Loan Rejected:Age criteria not met")
elif monthly_income<20000:
    print("Loan Rejected:Insufficient income")
elif credit_score<650:
    print("Loan Rejected: Low credit score")
elif employement_status!="employed":
    print("Loan Rejected: Employment required") 
else:
    print("Loan Approved")
# Out:
# Enter your age: 25
# Enter your monthly income: 25000
# Enter your credit score: 700
# Enter your employement status(employed/unemployed): employed
# Loan Approved

# %%
if credit_score>=750:
    print("Premium Loan")
elif 650<=credit_score<=749:
    print("standard")
else:
    print("Loan Rejected: Low credit score")
# Out:
# standard
